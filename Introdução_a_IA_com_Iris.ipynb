# %% [markdown]
# <a href="https://colab.research.google.com/github/l-abrahao/Lucas-Abrahao/blob/main/Introdu%C3%A7%C3%A3o_a_IA_com_Iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importando as Libs

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris

# %% [markdown]
# Carregando o DataSet

# %%
iris = load_iris()
iris_df = pd.DataFrame(iris.data, columns=iris.feature_names)
iris_df['species'] = pd.Categorical.from_codes(iris.target, iris.target_names)

print(iris_df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
print(iris_df.describe())
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %% [markdown]
# Quantas Amostras tem de Cada Espécie ?

# %%
print(iris_df['species'].value_counts())
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %% [markdown]
# Boxplot de Características por Espécie

# %%
plt.figure(figsize=(15,10))
for i ,feature in enumerate(iris.feature_names):
  plt.subplot(2,2, i+1)
  sns.boxplot(x = 'species', y = feature, data = iris_df)

plt.suptitle('Boxplot das Características por Espécies')
plt.show()

# %% [markdown]
# Pelo tamanho das pétalas já conseguimos identificar a espécie

# %% [markdown]
# Pairplot com Mapeamento de Cor

# %%
sns.pairplot(iris_df, hue = 'species')
plt.suptitle('Pairplot com Mapeamento de Cor por Espécie')
plt.show()

# %%
iris = load_iris()

# %% [markdown]
# Arvore de Decisão

# %%
#Importando o Dataset e Pré Processamento
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
iris = load_iris()
x_train, x_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.3)

# %%
#Importando a Decision Tree
from sklearn.tree import DecisionTreeClassifier
tree_model = DecisionTreeClassifier()
tree_model.fit(x_train, y_train)

#Avaliando o Modelo
predictions = tree_model.predict(x_test)

#Matriz de Confusão
conf_matrix = confusion_matrix(y_test, predictions)
print('Matriz de Confusão:\n', conf_matrix)

#Relatório de Classificação
class_rep = classification_report(y_test, predictions)
print('Relatório de Classificação:\n', class_rep)
# Out:
# Matriz de Confusão:
#  [[17  0  0]
#  [ 0 10  1]
#  [ 0  1 16]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        17
#            1       0.91      0.91      0.91        11
#            2       0.94      0.94      0.94        17
#
#     accuracy                           0.96        45
#    macro avg       0.95      0.95      0.95        45
# weighted avg       0.96      0.96      0.96        45

# %% [markdown]
# Visualização da Arvore

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(20,10))
tree.plot_tree(tree_model,feature_names=iris.feature_names, class_names=iris.target_names, filled=True, rounded=True, fontsize=12)
plt.title('Arvore de Decisão para o Dataset Iris')
plt.show()

# %% [markdown]
# MLP

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

#Modelo de Rede Neural
neural_model = MLPClassifier(hidden_layer_sizes=(10,5), max_iter=1000)
neural_model.fit(x_train, y_train)

#Avaliando o Modelo
predictions = neural_model.predict(x_test)

#Matriz de Confusão
conf_matrix = confusion_matrix(y_test, predictions)
print('Matriz de Confusão:\n', conf_matrix)

#Relatório de Classificação
class_rep = classification_report(y_test, predictions)
print('Relatório de Classificação:\n', class_rep)
# Out:
# Matriz de Confusão:
#  [[17  0  0]
#  [ 0  8  3]
#  [ 0  0 17]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        17
#            1       1.00      0.73      0.84        11
#            2       0.85      1.00      0.92        17
#
#     accuracy                           0.93        45
#    macro avg       0.95      0.91      0.92        45
# weighted avg       0.94      0.93      0.93        45

# %% [markdown]
# KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
import numpy as np

#Modelo KNN
knn_model = KNeighborsClassifier(n_neighbors=3)
knn_model.fit(x_train, y_train)

#Avaliando o Modelo
predictions = knn_model.predict(x_test)

#Matriz de Confusão
conf_matrix = confusion_matrix(y_test, predictions)
print('Matriz de Confusão:\n', conf_matrix)

#Relatório de Classificação
class_rep = classification_report(y_test, predictions)
print('Relatório de Classificação:\n', class_rep)
# Out:
# Matriz de Confusão:
#  [[17  0  0]
#  [ 0  9  2]
#  [ 0  0 17]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        17
#            1       1.00      0.82      0.90        11
#            2       0.89      1.00      0.94        17
#
#     accuracy                           0.96        45
#    macro avg       0.96      0.94      0.95        45
# weighted avg       0.96      0.96      0.95        45
